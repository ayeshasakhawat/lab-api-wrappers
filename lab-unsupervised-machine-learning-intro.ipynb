# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from random import randint
from time import sleep
from pandas import json_normalize

# K-means
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv('main_data.csv')
display(data.head())
data.shape
# Out:
#         artist                   song  popularity  \
# 0       Daphni  Cloudy - Kelbin Remix           0
# 1     Skrillex                 Rumble          84
# 2      altrice                   yoni          31
# 3  Junior Boys             Night Walk          23
# 4         Zaza              Nduzangou           0
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4OtqragtOuKh41rBNnFXuK         0.758   0.878   11    -6.656
# 1  spotify:track:1GfBLbAhZUWdseuDqhocmn         0.810   0.836    1    -7.721
# 2  spotify:track:0KpuGGkI2ELoGm7J8aDQbK         0.863   0.773   11    -3.944
# 3  spotify:track:1ufmBDHamjH3v8Ms1cyNsN         0.652   0.244    5   -21.979
# 4  spotify:track:261oqGIHQWXeBWoLNsnMDm         0.625   0.624    0    -7.812
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0549        0.3900            0.8660    0.1000   0.0668
# 1     0       0.0645        0.0515            0.2290    0.0598   0.0585
# 2     0       0.3400        0.4350            0.0599    0.1000   0.6620
# 3     1       0.0540        0.8320            0.9040    0.1330   0.5220
# 4     0       0.1390        0.3060            0.0000    0.1350   0.7690
#
#      tempo            type                      id  \
# 0  134.019  audio_features  4OtqragtOuKh41rBNnFXuK
# 1  139.979  audio_features  1GfBLbAhZUWdseuDqhocmn
# 2  123.339  audio_features  0KpuGGkI2ELoGm7J8aDQbK
# 3  169.810  audio_features  1ufmBDHamjH3v8Ms1cyNsN
# 4  119.975  audio_features  261oqGIHQWXeBWoLNsnMDm
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4OtqragtOuKh...
# 1  https://api.spotify.com/v1/tracks/1GfBLbAhZUWd...
# 2  https://api.spotify.com/v1/tracks/0KpuGGkI2ELo...
# 3  https://api.spotify.com/v1/tracks/1ufmBDHamjH3...
# 4  https://api.spotify.com/v1/tracks/261oqGIHQWXe...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4Otq...       336716
# 1  https://api.spotify.com/v1/audio-analysis/1GfB...       146571
# 2  https://api.spotify.com/v1/audio-analysis/0Kpu...       336230
# 3  https://api.spotify.com/v1/audio-analysis/1ufm...       289960
# 4  https://api.spotify.com/v1/audio-analysis/261o...       291273
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# (1336, 21)

# %%
data = data.drop_duplicates(subset='uri')

# %%
data_clustering = data.drop(['artist', 'song', 'uri', 'id', 'type','track_href', 'analysis_url','popularity'], axis = 1)

# %%
data_clustering.describe().T
# Out:
#                    count           mean            std           min  \
# danceability      1336.0       0.590815       0.183727      0.061000
# energy            1336.0       0.619402       0.218610      0.009780
# key               1336.0       5.626497       3.633038      0.000000
# loudness          1336.0     -10.825130       4.305466    -30.615000
# mode              1336.0       0.560629       0.496496      0.000000
# speechiness       1336.0       0.091747       0.093635      0.024900
# acousticness      1336.0       0.332210       0.319649      0.000005
# instrumentalness  1336.0       0.345423       0.382203      0.000000
# liveness          1336.0       0.180737       0.150538      0.009970
# valence           1336.0       0.555855       0.262149      0.028400
# tempo             1336.0     120.075356      25.700117     60.226000
# duration_ms       1336.0  312801.097305  189611.556350  25743.000000
# time_signature    1336.0       3.913174       0.402174      1.000000
#
#                             25%           50%           75%          max
# danceability           0.459000       0.61100       0.73800        0.963
# energy                 0.475750       0.64250       0.79825        0.998
# key                    2.000000       6.00000       9.00000       11.000
# loudness             -13.041000     -10.19600      -7.77275       -1.988
# mode                   0.000000       1.00000       1.00000        1.000
# speechiness            0.039100       0.05445       0.09295        0.792
# acousticness           0.036225       0.22650       0.61300        0.995
# instrumentalness       0.000560       0.09360       0.78925        0.996
# liveness               0.091775       0.11750       0.21600        0.984
# valence                0.358000       0.58400       0.77325        0.984
# tempo                100.856250     120.39050     131.83225      206.405
# duration_ms       201787.500000  268361.00000  364803.00000  1967427.000
# time_signature         4.000000       4.00000       4.00000        5.000

# %%
data_clustering = data_clustering.drop(['mode'], axis = 1)

# %%
data_clustering.to_csv("data_clustering.csv", index = False)

# %%
#Scaling the model

# %%
# The scale of "proline" is much higher than the scale of many other variables!
# K-Means is a distance based algorithm: we need to scale / normalize:

from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(data_clustering)

# Now, all features will have the same weight.
pd.DataFrame(X_prep,columns=data_clustering.columns).head()
# Out:
#    danceability    energy       key  loudness  speechiness  acousticness  \
# 0      0.910303  1.183364  1.479620  0.968697    -0.393671      0.180860
# 1      1.193437  0.991169 -1.273928  0.721244    -0.291107     -0.878509
# 2      1.482016  0.702877  1.479620  1.598830     2.652283      0.321692
# 3      0.333145 -1.717863 -0.172509 -2.591600    -0.403287      1.564143
# 4      0.186133  0.021043 -1.549283  0.700100     0.504837     -0.082026
#
#    instrumentalness  liveness   valence     tempo  duration_ms  time_signature
# 0          1.362555 -0.536524 -1.866257  0.542755     0.126173        0.215973
# 1         -0.304725 -0.803666 -1.897930  0.774747    -0.877016        0.215973
# 2         -0.747326 -0.536524  0.405056  0.127037     0.123609        0.215973
# 3          1.462016 -0.317228 -0.129191  1.935916    -0.120508        0.215973
# 4         -0.904108 -0.303937  0.813374 -0.003906    -0.113580        0.215973

# %%
# KMeans

# %%
import numpy as np
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
kmeans = KMeans(n_clusters=10, random_state=1234)
kmeans.fit(X_prep)
# Out:
# KMeans(n_clusters=10, random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    107
# 1     92
# 2    194
# 3    107
# 4    237
# 5    200
# 6     14
# 7    135
# 8     36
# 9    214
# dtype: int64

# %%
print(len(clusters))
clusters
# Out:
# 1336
# array([9, 7, 0, ..., 9, 9, 4], dtype=int32)

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:, 4], c=clusters,alpha=0.5)
plt.show()

# %%
kmeans.inertia_
# Out:
# 8777.622892980859

# %%
# %%time
kmeans = KMeans(n_clusters=8,
                init="random",
                n_init=1,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                random_state=1234)
kmeans.fit(X_prep)
print(kmeans.inertia_)
# Out:
# 10056.966333870083
# CPU times: user 41.3 ms, sys: 29.3 ms, total: 70.7 ms
# Wall time: 40.5 ms

# %%
data = data.assign(clusters = clusters)
data
# Out:
#                  artist                             song  popularity  \
# 0                Daphni            Cloudy - Kelbin Remix           0
# 1              Skrillex                           Rumble          84
# 2               altrice                             yoni          31
# 3           Junior Boys                       Night Walk          23
# 4                  Zaza                        Nduzangou           0
# ...                 ...                              ...         ...
# 1331  Teddy Pendergrass  The More I Get, the More I Want           0
# 1332       Todd Edwards                    Saved My Life          15
# 1333       Todd Edwards               Never Far From You           8
# 1334       Todd Edwards               Dancing For Heaven           6
# 1335       Todd Edwards                   You're The One           5
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:4OtqragtOuKh41rBNnFXuK         0.758   0.878   11
# 1     spotify:track:1GfBLbAhZUWdseuDqhocmn         0.810   0.836    1
# 2     spotify:track:0KpuGGkI2ELoGm7J8aDQbK         0.863   0.773   11
# 3     spotify:track:1ufmBDHamjH3v8Ms1cyNsN         0.652   0.244    5
# 4     spotify:track:261oqGIHQWXeBWoLNsnMDm         0.625   0.624    0
# ...                                    ...           ...     ...  ...
# 1331  spotify:track:2nsx3QznZwMFBPdE4PJiJJ         0.716   0.808    5
# 1332  spotify:track:7xR0hvWymbYc0GHSx4Jrxo         0.825   0.911    6
# 1333  spotify:track:076XkAjeMf7mfOgGsg3y67         0.894   0.917    6
# 1334  spotify:track:0i1y9HFHPquPLLIKnxJT23         0.866   0.932    6
# 1335  spotify:track:7DNpqqWLvAnPgE8ZqaeOQE         0.918   0.546    8
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -6.656     0       0.0549       0.39000            0.8660    0.1000
# 1       -7.721     0       0.0645       0.05150            0.2290    0.0598
# 2       -3.944     0       0.3400       0.43500            0.0599    0.1000
# 3      -21.979     1       0.0540       0.83200            0.9040    0.1330
# 4       -7.812     0       0.1390       0.30600            0.0000    0.1350
# ...        ...   ...          ...           ...               ...       ...
# 1331    -9.491     0       0.0662       0.33500            0.0000    0.0950
# 1332    -3.918     0       0.0522       0.00806            0.7800    0.3270
# 1333    -3.810     0       0.0904       0.04590            0.8760    0.0585
# 1334    -4.320     1       0.0581       0.00851            0.9090    0.0628
# 1335    -6.515     1       0.1230       0.01590            0.1540    0.0659
#
#       valence    tempo            type                      id  \
# 0      0.0668  134.019  audio_features  4OtqragtOuKh41rBNnFXuK
# 1      0.0585  139.979  audio_features  1GfBLbAhZUWdseuDqhocmn
# 2      0.6620  123.339  audio_features  0KpuGGkI2ELoGm7J8aDQbK
# 3      0.5220  169.810  audio_features  1ufmBDHamjH3v8Ms1cyNsN
# 4      0.7690  119.975  audio_features  261oqGIHQWXeBWoLNsnMDm
# ...       ...      ...             ...                     ...
# 1331   0.9020  121.243  audio_features  2nsx3QznZwMFBPdE4PJiJJ
# 1332   0.9820  124.949  audio_features  7xR0hvWymbYc0GHSx4Jrxo
# 1333   0.9270  124.995  audio_features  076XkAjeMf7mfOgGsg3y67
# 1334   0.9840  131.993  audio_features  0i1y9HFHPquPLLIKnxJT23
# 1335   0.7470  131.950  audio_features  7DNpqqWLvAnPgE8ZqaeOQE
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4OtqragtOuKh...
# 1     https://api.spotify.com/v1/tracks/1GfBLbAhZUWd...
# 2     https://api.spotify.com/v1/tracks/0KpuGGkI2ELo...
# 3     https://api.spotify.com/v1/tracks/1ufmBDHamjH3...
# 4     https://api.spotify.com/v1/tracks/261oqGIHQWXe...
# ...                                                 ...
# 1331  https://api.spotify.com/v1/tracks/2nsx3QznZwMF...
# 1332  https://api.spotify.com/v1/tracks/7xR0hvWymbYc...
# 1333  https://api.spotify.com/v1/tracks/076XkAjeMf7m...
# 1334  https://api.spotify.com/v1/tracks/0i1y9HFHPquP...
# 1335  https://api.spotify.com/v1/tracks/7DNpqqWLvAnP...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4Otq...       336716
# 1     https://api.spotify.com/v1/audio-analysis/1GfB...       146571
# 2     https://api.spotify.com/v1/audio-analysis/0Kpu...       336230
# 3     https://api.spotify.com/v1/audio-analysis/1ufm...       289960
# 4     https://api.spotify.com/v1/audio-analysis/261o...       291273
# ...                                                 ...          ...
# 1331  https://api.spotify.com/v1/audio-analysis/2nsx...       264613
# 1332  https://api.spotify.com/v1/audio-analysis/7xR0...       415730
# 1333  https://api.spotify.com/v1/audio-analysis/076X...       400748
# 1334  https://api.spotify.com/v1/audio-analysis/0i1y...       349624
# 1335  https://api.spotify.com/v1/audio-analysis/7DNp...       394578
#
#       time_signature  clusters
# 0                  4         9
# 1                  4         7
# 2                  4         0
# 3                  4         5
# 4                  4         2
# ...              ...       ...
# 1331               4         4
# 1332               4         9
# 1333               4         9
# 1334               4         9
# 1335               4         4
#
# [1336 rows x 22 columns]

# %%
data[data['clusters'] == 5]
# Out:
#                                   artist  \
# 3                            Junior Boys
# 6                       LaRhonda LeGette
# 8                  Joel Vandroogenbroeck
# 10                                Daphni
# 21    Captain Beefheart & His Magic Band
# ...                                  ...
# 1308                                Gong
# 1315                        James Dashow
# 1317                         James Tatum
# 1318                         James Tatum
# 1322               Joel Vandroogenbroeck
#
#                                           song  popularity  \
# 3                                   Night Walk          23
# 6                             Thou Art With Me          13
# 8                                   Fairy Tale          17
# 10                                  Arp Blocks          35
# 21                           Observatory Crest          41
# ...                                        ...         ...
# 1308   Love Is How You Make It - 2015 Remaster          11
# 1315  Oedipus Orca - Theme From "Oedipus Orca"          31
# 1317                                  Alleluia           2
# 1318                           Lord Have Mercy           5
# 1322                            Nilotic Sounds           9
#
#                                        uri  danceability  energy  key  \
# 3     spotify:track:1ufmBDHamjH3v8Ms1cyNsN         0.652  0.2440    5
# 6     spotify:track:3BN1Cwn8Z8JxvWIzq9nE7A         0.395  0.3380    9
# 8     spotify:track:2b8UOiBgWEaqNxHzj40oai         0.728  0.0850    4
# 10    spotify:track:16nMtzomkigsObsp4d4Dvv         0.857  0.0986   10
# 21    spotify:track:0FQcRQEGbJjNny5G0A2hle         0.640  0.4050    7
# ...                                    ...           ...     ...  ...
# 1308  spotify:track:1f9mUCRfDWwHoHXk7bbKWB         0.503  0.4270   11
# 1315  spotify:track:4L3V6gIlLrApJh3nCf2XLY         0.418  0.6550    1
# 1317  spotify:track:1JF3nzgACt8hTdOUhx5RdH         0.270  0.3140    7
# 1318  spotify:track:3D1uRaQDt2i8pbiAtV8kR2         0.306  0.1500    9
# 1322  spotify:track:0Nr8zDeVYZM7wy3US39sL4         0.565  0.6590    4
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 3      -21.979     1       0.0540         0.832            0.9040    0.1330
# 6      -12.271     0       0.0306         0.880            0.4610    0.1680
# 8      -25.631     0       0.2330         0.925            0.8310    0.0992
# 10     -20.584     1       0.1170         0.989            0.1210    0.1180
# 21     -14.358     1       0.0441         0.679            0.6520    0.1150
# ...        ...   ...          ...           ...               ...       ...
# 1308   -13.956     1       0.0435         0.654            0.0216    0.0719
# 1315   -18.576     1       0.1560         0.622            0.8970    0.0948
# 1317   -15.629     0       0.0316         0.889            0.5160    0.0991
# 1318   -18.007     0       0.0358         0.903            0.1980    0.0874
# 1322   -17.199     0       0.0570         0.927            0.9550    0.2160
#
#       valence    tempo            type                      id  \
# 3       0.522  169.810  audio_features  1ufmBDHamjH3v8Ms1cyNsN
# 6       0.077   80.017  audio_features  3BN1Cwn8Z8JxvWIzq9nE7A
# 8       0.753  142.199  audio_features  2b8UOiBgWEaqNxHzj40oai
# 10      0.451  126.103  audio_features  16nMtzomkigsObsp4d4Dvv
# 21      0.587   95.119  audio_features  0FQcRQEGbJjNny5G0A2hle
# ...       ...      ...             ...                     ...
# 1308    0.469  117.589  audio_features  1f9mUCRfDWwHoHXk7bbKWB
# 1315    0.564   83.611  audio_features  4L3V6gIlLrApJh3nCf2XLY
# 1317    0.277  103.883  audio_features  1JF3nzgACt8hTdOUhx5RdH
# 1318    0.137  138.880  audio_features  3D1uRaQDt2i8pbiAtV8kR2
# 1322    0.861  109.313  audio_features  0Nr8zDeVYZM7wy3US39sL4
#
#                                              track_href  \
# 3     https://api.spotify.com/v1/tracks/1ufmBDHamjH3...
# 6     https://api.spotify.com/v1/tracks/3BN1Cwn8Z8Jx...
# 8     https://api.spotify.com/v1/tracks/2b8UOiBgWEaq...
# 10    https://api.spotify.com/v1/tracks/16nMtzomkigs...
# 21    https://api.spotify.com/v1/tracks/0FQcRQEGbJjN...
# ...                                                 ...
# 1308  https://api.spotify.com/v1/tracks/1f9mUCRfDWwH...
# 1315  https://api.spotify.com/v1/tracks/4L3V6gIlLrAp...
# 1317  https://api.spotify.com/v1/tracks/1JF3nzgACt8h...
# 1318  https://api.spotify.com/v1/tracks/3D1uRaQDt2i8...
# 1322  https://api.spotify.com/v1/tracks/0Nr8zDeVYZM7...
#
#                                            analysis_url  duration_ms  \
# 3     https://api.spotify.com/v1/audio-analysis/1ufm...       289960
# 6     https://api.spotify.com/v1/audio-analysis/3BN1...       107853
# 8     https://api.spotify.com/v1/audio-analysis/2b8U...       180279
# 10    https://api.spotify.com/v1/audio-analysis/16nM...       129865
# 21    https://api.spotify.com/v1/audio-analysis/0FQc...       212907
# ...                                                 ...          ...
# 1308  https://api.spotify.com/v1/audio-analysis/1f9m...       207533
# 1315  https://api.spotify.com/v1/audio-analysis/4L3V...       138693
# 1317  https://api.spotify.com/v1/audio-analysis/1JF3...       243447
# 1318  https://api.spotify.com/v1/audio-analysis/3D1u...       381497
# 1322  https://api.spotify.com/v1/audio-analysis/0Nr8...       180949
#
#       time_signature  clusters
# 3                  4         5
# 6                  4         5
# 8                  4         5
# 10                 4         5
# 21                 4         5
# ...              ...       ...
# 1308               4         5
# 1315               4         5
# 1317               4         5
# 1318               4         5
# 1322               4         5
#
# [200 rows x 22 columns]

# %%
data.to_csv("data_recommender.csv", index = False)
